# %%
import pandas as pd
import numpy as np
from datetime import datetime
from datetime import datetime as dt
import time

# %%
# Load dataset in and view the first five rows
busData = pd.read_csv("data_business_reg/Registered_Business_SF.csv")
busData.head()
# Out:
# /Users/tinahuang/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (12,13,14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       Location Id  Business Account Number                 Ownership Name  \
# 0  0030032-46-001                    30032                    Walgreen Co
# 1  1280241-06-211                    15092                   Jug Shop Inc
# 2  1012834-11-141                    91116     Urban Land Services Of Cal
# 3  0348331-01-001                   348331                Tran Sandy Dung
# 4  1281008-06-211                    18971  Merrill Lynch Pierce Etal Inc
#
#                      DBA Name         Street Address           City State  \
# 0            Walgreens #15567          845 Market St  San Francisco    CA
# 1               Jug Shop Inc.       1648 Pacific Ave  San Francisco    CA
# ...

# %% [markdown]
# ## Delete unecessary columns

# %%
#Drop unecessary columns
clean_data = busData.drop(['Location Id','Business Account Number','Business End Date'], axis = 1)
# Drop all rows with missing information
clean_data.dropna(how='any')
clean_data.head()
# Out:
#                   Ownership Name                    DBA Name  \
# 0                    Walgreen Co            Walgreens #15567
# 1                   Jug Shop Inc               Jug Shop Inc.
# 2     Urban Land Services Of Cal  Urban Land Services Of Cal
# 3                Tran Sandy Dung       Elizabeth Hair Studio
# 4  Merrill Lynch Pierce Etal Inc                     Merrill
#
#           Street Address           City State Source Zipcode  \
# 0          845 Market St  San Francisco    CA          94103
# 1       1648 Pacific Ave  San Francisco    CA          94109
# 2  1170 Sacramento St 5d  San Francisco    CA          94108
# 3           672 Geary St  San Francisco    CA          94102
# 4           1275 Fell St  San Francisco    CA          94117
#
#   Business Start Date Location Start Date Location End Date  \
# 0           10/1/1968           1/24/2014         1/25/2014
# 1           10/1/1968           6/14/2021               NaN
# ...

# %%
# Export data to CSV
clean_data.to_csv('cleaneddata.csv')
